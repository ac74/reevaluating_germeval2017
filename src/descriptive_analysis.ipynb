# %% [markdown]
# # Descriptive analysis of GermEval 2017 data (latest version from 2017-09-15)

# %%
#!/usr/bin/env python3
import os
import pandas as pd
import numpy as np
from utils import flatten_list
from seqeval_metrics import get_entities
from data_prep import bio_tagging_df

df_path = "./data/"

# Load complete pre-processed data
train_df = pd.read_csv(df_path + "train_df.tsv", delimiter = '\t')
dev_df = pd.read_csv(df_path + "dev_df.tsv", delimiter = '\t')
test_syn_df = pd.read_csv(df_path + "test_syn_df.tsv", delimiter = '\t')
test_syn_df = test_syn_df.dropna(subset = ["text"])    
test_dia_df = pd.read_csv(df_path + "test_dia_df.tsv", delimiter = '\t')

train_df_op = pd.read_csv(df_path + "train_df_opinion.tsv", delimiter = '\t')
dev_df_op = pd.read_csv(df_path + "dev_df_opinion.tsv", delimiter = '\t')
test_syn_df_op = pd.read_csv(df_path + "test_syn_df_opinion.tsv", delimiter = '\t')
test_dia_df_op = pd.read_csv(df_path + "test_dia_df_opinion.tsv", delimiter = '\t')

train_df_cat = pd.read_csv(df_path + "train_df_cat.tsv", delimiter = '\t')
dev_df_cat = pd.read_csv(df_path + "dev_df_cat.tsv", delimiter = '\t')
test_syn_df_cat = pd.read_csv(df_path + "test_syn_df_cat.tsv", delimiter = '\t')
test_dia_df_cat = pd.read_csv(df_path + "test_dia_df_cat.tsv", delimiter = '\t')

train_df_cat_pol = pd.read_csv(df_path + "train_df_cat_pol.tsv", delimiter = '\t')
dev_df_cat_pol = pd.read_csv(df_path + "dev_df_cat_pol.tsv", delimiter = '\t')
test_syn_df_cat_pol = pd.read_csv(df_path + "test_syn_df_cat_pol.tsv", delimiter = '\t')
test_dia_df_cat_pol = pd.read_csv(df_path + "test_dia_df_cat_pol.tsv", delimiter = '\t')

cats = train_df_cat.columns[5:]
cats_pol = train_df_cat_pol.columns[5:]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-73c435b5fc42> in <module>
#      10
#      11 # Load complete pre-processed data
# ---> 12 train_df = pd.read_csv(df_path + "train_df.tsv", delimiter = '\t')
#      13 dev_df = pd.read_csv(df_path + "dev_df.tsv", delimiter = '\t')
#      14 test_syn_df = pd.read_csv(df_path + "test_syn_df.tsv", delimiter = '\t')
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     603     kwds.update(kwds_defaults)
#     604
# --> 605     return _read(filepath_or_buffer, kwds)
#     606
#     607
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(filepath_or_buffer, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     812             self.options["has_index_names"] = kwds["has_index_names"]
#     813
# --> 814         self._engine = self._make_engine(self.engine)
#     815
#     816     def close(self):
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1043             )
#    1044         # error: Too many arguments for "ParserBase"
# -> 1045         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1046
#    1047     def _failover_to_python(self):
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1860
#    1861         # open handles
# -> 1862         self._open_handles(src, kwds)
#    1863         assert self.handles is not None
#    1864         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers.py in _open_handles(self, src, kwds)
#    1355         Let the readers open IOHanldes after they are done with their potential raises.
#    1356         """
# -> 1357         self.handles = get_handle(
#    1358             src,
#    1359             "r",
#
# ~/.local/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     637         if ioargs.encoding and "b" not in ioargs.mode:
#     638             # Encoding
# --> 639             handle = open(
#     640                 handle,
#     641                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/train_df.tsv'

# %%
def count_bio_tags(df):
    df = bio_tagging_df(df)
    tags = get_entities(flatten_list(df.bio_tags))
    entities = [tag[0] for tag in tags]
    ent_dict = {'bio_tags': entities}
    entities_df = pd.DataFrame(data=ent_dict)
    report = entities_df['bio_tags'].value_counts()
    return report


def desc_analysis(df, df_op, df_cat, df_cat_pol, cats, cats_pol):
    print("complete number of observations")
    print(len(df))
    print()

    print("relevance distribution") #subtask A
    print(pd.crosstab(df["relevance"], columns = "count").sort_values(by = "count", ascending = False))
    print()

    print("sentiment distribution") # subtask B
    print(pd.crosstab(df["sentiment"], columns = "count").sort_values(by = "count", ascending = False))
    print()

    print("aspect distribution of documents with opinion") # Subtask C
    print(pd.crosstab(df_op["aspect"], columns = "count").sort_values(by = "count", ascending = False))
    print()
    print(pd.crosstab(df_op['aspect_polarity'], columns = "count").sort_values(by = "count", ascending = False))
    print("total documents: ", len(train_df_op))
    print()

    print("aspect distribution without multiple mentions")
    print(df_cat[cats].sum(axis = 0, skipna = True))
    print()
    print(df_cat_pol[cats_pol].sum(axis = 0, skipna = True))
    print()

    print("entity distribution") # Subtask D
    print(count_bio_tags(train_df_op))
    print()

# %% [markdown]
# ## Train data

# %%
desc_analysis(train_df, train_df_op, train_df_cat, train_df_cat_pol, cats, cats_pol)
# Out:
# complete number of observations
# 19432
#
# relevance distribution
# col_0      count
# relevance
# True       16201
# False       3231
#
# sentiment distribution
# col_0      count
# sentiment
# neutral    13208
# negative    5045
# positive    1179
#
# aspect distribution of documents with opinion
# col_0                         count
# aspect
# Allgemein                     12385
# Zugfahrt                       2189
# Sonstige_Unregelmässigkeiten   1918
# Atmosphäre                     1405
# Sicherheit                      859
# Ticketkauf                      661
# Service_und_Kundenbetreuung     504
# Connectivity                    360
# Informationen                   354
# Auslastung_und_Platzangebot     272
# DB_App_und_Website              228
# Komfort_und_Ausstattung         148
# Barrierefreiheit                 72
# Toiletten                        49
# Image                            48
# Reisen_mit_Kindern               43
# Gastronomisches_Angebot          43
# Design                           33
# Gepäck                           13
#
# col_0                                  count
# aspect_polarity
# Allgemein:neutral                       9465
# nan:nan                                 3232
# Allgemein:negative                      1878
# Sonstige_Unregelmässigkeiten:negative   1766
# Zugfahrt:negative                       1642
# Atmosphäre:negative                     1063
# Allgemein:positive                      1042
# Sicherheit:negative                      826
# Ticketkauf:negative                      462
# Zugfahrt:positive                        395
# Service_und_Kundenbetreuung:negative     330
# Informationen:negative                   247
# Connectivity:negative                    230
# Auslastung_und_Platzangebot:negative     224
# Atmosphäre:neutral                       211
# Zugfahrt:neutral                         152
# Atmosphäre:positive                      131
# Service_und_Kundenbetreuung:positive     128
# DB_App_und_Website:negative              119
# Ticketkauf:neutral                       109
# Ticketkauf:positive                       90
# Sonstige_Unregelmässigkeiten:neutral      89
# Komfort_und_Ausstattung:negative          88
# DB_App_und_Website:neutral                72
# Connectivity:positive                     68
# Informationen:neutral                     64
# Sonstige_Unregelmässigkeiten:positive     63
# Connectivity:neutral                      62
# Service_und_Kundenbetreuung:neutral       46
# Barrierefreiheit:negative                 44
# Informationen:positive                    43
# Auslastung_und_Platzangebot:positive      40
# Toiletten:negative                        37
# DB_App_und_Website:positive               37
# Komfort_und_Ausstattung:positive          36
# Image:negative                            29
# Gastronomisches_Angebot:negative          26
# Komfort_und_Ausstattung:neutral           24
# Reisen_mit_Kindern:negative               19
# Sicherheit:positive                       19
# Reisen_mit_Kindern:neutral                15
# Design:negative                           15
# Barrierefreiheit:positive                 15
# Design:positive                           14
# Sicherheit:neutral                        14
# Barrierefreiheit:neutral                  13
# Image:neutral                             11
# Toiletten:neutral                         10
# Reisen_mit_Kindern:positive                9
# Gastronomisches_Angebot:neutral            9
# Auslastung_und_Platzangebot:neutral        8
# Image:positive                             8
# Gastronomisches_Angebot:positive           8
# Gepäck:neutral                             7
# Gepäck:negative                            6
# Design:neutral                             4
# Toiletten:positive                         2
# total documents:  24816
#
# aspect distribution without multiple
# Allgemein                       11454
# Atmosphäre                        990
# Informationen                     306
# DB_App_und_Website                175
# Auslastung_und_Platzangebot       231
# Sonstige_Unregelmässigkeiten     1277
# Zugfahrt                         1687
# Ticketkauf                        540
# Sicherheit                        405
# Barrierefreiheit                   53
# Service_und_Kundenbetreuung       447
# Connectivity                      250
# Komfort_und_Ausstattung           125
# Toiletten                          41
# Gastronomisches_Angebot            38
# Image                              42
# Design                             29
# Reisen_mit_Kindern                 35
# Gepäck                             12
# QR-Code                             0
# dtype: int64
# Allgemein:negative                       1443
# Allgemein:neutral                        9447
# Allgemein:positive                        744
# Atmosphäre:negative                       802
# Atmosphäre:neutral                        172
# Atmosphäre:positive                       116
# Auslastung_und_Platzangebot:negative      196
# Auslastung_und_Platzangebot:neutral         7
# Auslastung_und_Platzangebot:positive       34
# Barrierefreiheit:negative                  33
# Barrierefreiheit:neutral                   10
# Barrierefreiheit:positive                  12
# Connectivity:negative                     173
# Connectivity:neutral                       47
# Connectivity:positive                      56
# DB_App_und_Website:negative               103
# DB_App_und_Website:neutral                 53
# DB_App_und_Website:positive                31
# Design:negative                            14
# Design:neutral                              3
# Design:positive                            14
# Gastronomisches_Angebot:negative           26
# Gastronomisches_Angebot:neutral             9
# Gastronomisches_Angebot:positive            7
# Gepäck:negative                             5
# Gepäck:neutral                              7
# Gepäck:positive                             0
# Image:negative                             25
# Image:neutral                              11
# Image:positive                              6
# Informationen:negative                    213
# Informationen:neutral                      58
# Informationen:positive                     42
# Komfort_und_Ausstattung:negative           77
# Komfort_und_Ausstattung:neutral            22
# Komfort_und_Ausstattung:positive           30
# QR-Code:negative                            0
# QR-Code:neutral                             0
# QR-Code:positive                            0
# Reisen_mit_Kindern:negative                17
# Reisen_mit_Kindern:neutral                 14
# Reisen_mit_Kindern:positive                 7
# Service_und_Kundenbetreuung:negative      298
# Service_und_Kundenbetreuung:neutral        45
# Service_und_Kundenbetreuung:positive      113
# Sicherheit:negative                       383
# Sicherheit:neutral                         13
# Sicherheit:positive                        16
# Sonstige_Unregelmässigkeiten:negative    1196
# Sonstige_Unregelmässigkeiten:neutral       81
# Sonstige_Unregelmässigkeiten:positive      57
# Ticketkauf:negative                       392
# Ticketkauf:neutral                         92
# Ticketkauf:positive                        81
# Toiletten:negative                         31
# Toiletten:neutral                           8
# Toiletten:positive                          2
# Zugfahrt:negative                        1323
# Zugfahrt:neutral                          132
# Zugfahrt:positive                         308
# dtype: int64
#
# entity distribution
# ALG:NEG    1795
# SOU:NEG    1766
# ZUG:NEG    1642
# ATM:NEG    1063
# ALG:POS    1029
# SIC:NEG     826
# TIC:NEG     462
# ZUG:POS     395
# SUK:NEG     330
# INF:NEG     247
# CON:NEG     230
# AUP:NEG     224
# ATM:NEU     211
# ZUG:NEU     151
# ATM:POS     131
# SUK:POS     128
# ALG:NEU     123
# APP:NEG     119
# TIC:NEU     107
# TIC:POS      90
# SOU:NEU      89
# KUA:NEG      88
# APP:NEU      72
# CON:POS      68
# INF:NEU      64
# SOU:POS      63
# CON:NEU      62
# SUK:NEU      46
# BAF:NEG      44
# INF:POS      43
# AUP:POS      40
# APP:POS      37
# TOI:NEG      37
# KUA:POS      36
# IMG:NEG      29
# GST:NEG      26
# KUA:NEU      21
# SIC:POS      19
# RMK:NEG      19
# BAF:POS      15
# DSG:NEG      15
# RMK:NEU      15
# SIC:NEU      14
# DSG:POS      14
# BAF:NEU      13
# IMG:NEU      11
# TOI:NEU      10
# RMK:POS       9
# GST:NEU       9
# AUP:NEU       8
# GST:POS       8
# IMG:POS       8
# GEP:NEU       7
# GEP:NEG       6
# DSG:NEU       3
# TOI:POS       2
# Name: bio_tags, dtype: int64

# %% [markdown]
# ## Development data

# %%
desc_analysis(dev_df, dev_df_op, dev_df_cat, dev_df_cat_pol, cats, cats_pol)
# Out:
# complete number of observations
# 2369
#
# relevance distribution
# col_0      count
# relevance
# True        1931
# False        438
#
# sentiment distribution
# col_0      count
# sentiment
# neutral     1632
# negative     589
# positive     148
#
# aspect distribution of documents with opinion
# col_0                         count
# aspect
# Allgemein                      1507
# Zugfahrt                        232
# Sonstige_Unregelmässigkeiten    194
# Atmosphäre                      171
# Sicherheit                      103
# Ticketkauf                       80
# Service_und_Kundenbetreuung      47
# Informationen                    34
# Auslastung_und_Platzangebot      32
# Connectivity                     30
# DB_App_und_Website               24
# Komfort_und_Ausstattung          18
# Barrierefreiheit                 17
# Image                             6
# Toiletten                         5
# Gastronomisches_Angebot           4
# Design                            4
# Reisen_mit_Kindern                3
# Gepäck                            2
# QR-Code                           1
#
# col_0                                  count
# aspect_polarity
# Allgemein:neutral                       1133
# nan:nan                                  439
# Allgemein:negative                       236
# Sonstige_Unregelmässigkeiten:negative    184
# Zugfahrt:negative                        161
# Allgemein:positive                       138
# Atmosphäre:negative                      135
# Sicherheit:negative                      100
# Ticketkauf:negative                       54
# Zugfahrt:positive                         51
# Service_und_Kundenbetreuung:negative      28
# Atmosphäre:neutral                        25
# Informationen:negative                    24
# Auslastung_und_Platzangebot:negative      24
# Zugfahrt:neutral                          20
# Connectivity:negative                     17
# Ticketkauf:neutral                        16
# DB_App_und_Website:negative               13
# Service_und_Kundenbetreuung:positive      13
# Connectivity:positive                     12
# Barrierefreiheit:negative                 12
# Atmosphäre:positive                       11
# Ticketkauf:positive                       10
# Komfort_und_Ausstattung:negative          10
# Informationen:neutral                      8
# Auslastung_und_Platzangebot:positive       7
# Sonstige_Unregelmässigkeiten:neutral       7
# Service_und_Kundenbetreuung:neutral        6
# DB_App_und_Website:positive                6
# Komfort_und_Ausstattung:positive           6
# DB_App_und_Website:neutral                 5
# Sonstige_Unregelmässigkeiten:positive      3
# Design:negative                            3
# Barrierefreiheit:positive                  3
# Image:positive                             3
# Toiletten:negative                         3
# Toiletten:neutral                          2
# Sicherheit:neutral                         2
# Reisen_mit_Kindern:negative                2
# Informationen:positive                     2
# Barrierefreiheit:neutral                   2
# Komfort_und_Ausstattung:neutral            2
# Image:neutral                              2
# Gepäck:negative                            2
# Gastronomisches_Angebot:neutral            2
# Gastronomisches_Angebot:negative           2
# Sicherheit:positive                        1
# Reisen_mit_Kindern:neutral                 1
# QR-Code:positive                           1
# Auslastung_und_Platzangebot:neutral        1
# Image:negative                             1
# Design:positive                            1
# Connectivity:neutral                       1
# total documents:  24816
#
# aspect distribution without multiple
# Allgemein                       1391
# Atmosphäre                       128
# Informationen                     28
# DB_App_und_Website                20
# Auslastung_und_Platzangebot       25
# Sonstige_Unregelmässigkeiten     139
# Zugfahrt                         177
# Ticketkauf                        64
# Sicherheit                        59
# Barrierefreiheit                  14
# Service_und_Kundenbetreuung       42
# Connectivity                      22
# Komfort_und_Ausstattung           18
# Toiletten                          5
# Gastronomisches_Angebot            2
# Image                              6
# Design                             3
# Reisen_mit_Kindern                 3
# Gepäck                             2
# QR-Code                            1
# dtype: int64
# Allgemein:negative                        188
# Allgemein:neutral                        1133
# Allgemein:positive                         91
# Atmosphäre:negative                       105
# Atmosphäre:neutral                         20
# Atmosphäre:positive                        11
# Auslastung_und_Platzangebot:negative       20
# Auslastung_und_Platzangebot:neutral         1
# Auslastung_und_Platzangebot:positive        7
# Barrierefreiheit:negative                  10
# Barrierefreiheit:neutral                    2
# Barrierefreiheit:positive                   3
# Connectivity:negative                      13
# Connectivity:neutral                        1
# Connectivity:positive                       8
# DB_App_und_Website:negative                11
# DB_App_und_Website:neutral                  5
# DB_App_und_Website:positive                 6
# Design:negative                             2
# Design:neutral                              0
# Design:positive                             1
# Gastronomisches_Angebot:negative            2
# Gastronomisches_Angebot:neutral             1
# Gastronomisches_Angebot:positive            0
# Gepäck:negative                             2
# Gepäck:neutral                              0
# Gepäck:positive                             0
# Image:negative                              1
# Image:neutral                               2
# Image:positive                              3
# Informationen:negative                     21
# Informationen:neutral                       6
# Informationen:positive                      2
# Komfort_und_Ausstattung:negative           10
# Komfort_und_Ausstattung:neutral             2
# Komfort_und_Ausstattung:positive            6
# QR-Code:negative                            0
# QR-Code:neutral                             0
# QR-Code:positive                            1
# Reisen_mit_Kindern:negative                 2
# Reisen_mit_Kindern:neutral                  1
# Reisen_mit_Kindern:positive                 0
# Service_und_Kundenbetreuung:negative       26
# Service_und_Kundenbetreuung:neutral         5
# Service_und_Kundenbetreuung:positive       13
# Sicherheit:negative                        58
# Sicherheit:neutral                          1
# Sicherheit:positive                         1
# Sonstige_Unregelmässigkeiten:negative     133
# Sonstige_Unregelmässigkeiten:neutral        5
# Sonstige_Unregelmässigkeiten:positive       3
# Ticketkauf:negative                        47
# Ticketkauf:neutral                         10
# Ticketkauf:positive                         8
# Toiletten:negative                          3
# Toiletten:neutral                           2
# Toiletten:positive                          0
# Zugfahrt:negative                         132
# Zugfahrt:neutral                           19
# Zugfahrt:positive                          38
# dtype: int64
#
# entity distribution
# ALG:NEG    1795
# SOU:NEG    1766
# ZUG:NEG    1642
# ATM:NEG    1063
# ALG:POS    1029
# SIC:NEG     826
# TIC:NEG     462
# ZUG:POS     395
# SUK:NEG     330
# INF:NEG     247
# CON:NEG     230
# AUP:NEG     224
# ATM:NEU     211
# ZUG:NEU     151
# ATM:POS     131
# SUK:POS     128
# ALG:NEU     123
# APP:NEG     119
# TIC:NEU     107
# TIC:POS      90
# SOU:NEU      89
# KUA:NEG      88
# APP:NEU      72
# CON:POS      68
# INF:NEU      64
# SOU:POS      63
# CON:NEU      62
# SUK:NEU      46
# BAF:NEG      44
# INF:POS      43
# AUP:POS      40
# APP:POS      37
# TOI:NEG      37
# KUA:POS      36
# IMG:NEG      29
# GST:NEG      26
# KUA:NEU      21
# SIC:POS      19
# RMK:NEG      19
# BAF:POS      15
# DSG:NEG      15
# RMK:NEU      15
# SIC:NEU      14
# DSG:POS      14
# BAF:NEU      13
# IMG:NEU      11
# TOI:NEU      10
# RMK:POS       9
# GST:NEU       9
# AUP:NEU       8
# GST:POS       8
# IMG:POS       8
# GEP:NEU       7
# GEP:NEG       6
# DSG:NEU       3
# TOI:POS       2
# Name: bio_tags, dtype: int64

# %% [markdown]
# ## Synchronic test data

# %%
desc_analysis(test_syn_df, test_syn_df_op, test_syn_df_cat, test_syn_df_cat_pol, cats, cats_pol)
# Out:
# complete number of observations
# 2555
#
# relevance distribution
# col_0      count
# relevance
# True        2095
# False        460
#
# sentiment distribution
# col_0      count
# sentiment
# neutral     1670
# negative     780
# positive     105
#
# aspect distribution of documents with opinion
# col_0                         count
# aspect
# Allgemein                      1573
# Sonstige_Unregelmässigkeiten    373
# Zugfahrt                        325
# Atmosphäre                      272
# Sicherheit                      197
# Ticketkauf                      158
# Service_und_Kundenbetreuung      79
# Informationen                    79
# Connectivity                     51
# Auslastung_und_Platzangebot      44
# DB_App_und_Website               35
# Komfort_und_Ausstattung          29
# Barrierefreiheit                 13
# Reisen_mit_Kindern               10
# Toiletten                         8
# Design                            6
# Gastronomisches_Angebot           6
# Gepäck                            2
# QR-Code                           1
#
# col_0                                  count
# aspect_polarity
# Allgemein:neutral                       1112
# nan:nan                                  471
# Allgemein:negative                       414
# Sonstige_Unregelmässigkeiten:negative    365
# Zugfahrt:negative                        251
# Atmosphäre:negative                      222
# Sicherheit:negative                      188
# Ticketkauf:neutral                        76
# Zugfahrt:positive                         51
# Ticketkauf:negative                       50
# Allgemein:positive                        47
# Service_und_Kundenbetreuung:negative      43
# Informationen:negative                    37
# Informationen:neutral                     37
# Auslastung_und_Platzangebot:negative      37
# Ticketkauf:positive                       32
# Atmosphäre:neutral                        28
# Connectivity:negative                     27
# Zugfahrt:neutral                          23
# Atmosphäre:positive                       22
# DB_App_und_Website:negative               20
# Service_und_Kundenbetreuung:neutral       20
# Service_und_Kundenbetreuung:positive      16
# Connectivity:positive                     16
# DB_App_und_Website:neutral                12
# Komfort_und_Ausstattung:negative          10
# Komfort_und_Ausstattung:neutral           10
# Komfort_und_Ausstattung:positive           9
# Connectivity:neutral                       8
# Sicherheit:positive                        6
# Barrierefreiheit:negative                  6
# Sonstige_Unregelmässigkeiten:neutral       5
# Auslastung_und_Platzangebot:positive       5
# Toiletten:negative                         5
# Reisen_mit_Kindern:neutral                 5
# Barrierefreiheit:positive                  5
# Reisen_mit_Kindern:negative                5
# Design:positive                            5
# Informationen:positive                     5
# Gastronomisches_Angebot:negative           4
# Sonstige_Unregelmässigkeiten:positive      3
# Sicherheit:neutral                         3
# Toiletten:neutral                          3
# DB_App_und_Website:positive                3
# Auslastung_und_Platzangebot:neutral        2
# Barrierefreiheit:neutral                   2
# QR-Code:neutral                            1
# Gepäck:neutral                             1
# Gepäck:negative                            1
# Gastronomisches_Angebot:neutral            1
# Design:negative                            1
# Gastronomisches_Angebot:positive           1
# total documents:  24816
#
# aspect distribution without multiple
# Allgemein                       1398
# Atmosphäre                       148
# Informationen                     58
# DB_App_und_Website                28
# Auslastung_und_Platzangebot       35
# Sonstige_Unregelmässigkeiten     224
# Zugfahrt                         241
# Ticketkauf                        95
# Sicherheit                        84
# Barrierefreiheit                   9
# Service_und_Kundenbetreuung       63
# Connectivity                      36
# Komfort_und_Ausstattung           24
# Toiletten                          7
# Gastronomisches_Angebot            3
# Image                              0
# Design                             4
# Reisen_mit_Kindern                 7
# Gepäck                             2
# QR-Code                            1
# dtype: int64
# Allgemein:negative                        258
# Allgemein:neutral                        1108
# Allgemein:positive                         41
# Atmosphäre:negative                       126
# Atmosphäre:neutral                         24
# Atmosphäre:positive                        14
# Auslastung_und_Platzangebot:negative       31
# Auslastung_und_Platzangebot:neutral         2
# Auslastung_und_Platzangebot:positive        4
# Barrierefreiheit:negative                   4
# Barrierefreiheit:neutral                    2
# Barrierefreiheit:positive                   3
# Connectivity:negative                      20
# Connectivity:neutral                        8
# Connectivity:positive                      13
# DB_App_und_Website:negative                16
# DB_App_und_Website:neutral                 11
# DB_App_und_Website:positive                 3
# Design:negative                             1
# Design:neutral                              0
# Design:positive                             3
# Gastronomisches_Angebot:negative            2
# Gastronomisches_Angebot:neutral             1
# Gastronomisches_Angebot:positive            1
# Gepäck:negative                             1
# Gepäck:neutral                              1
# Gepäck:positive                             0
# Image:negative                              0
# Image:neutral                               0
# Image:positive                              0
# Informationen:negative                     29
# Informationen:neutral                      26
# Informationen:positive                      5
# Komfort_und_Ausstattung:negative            9
# Komfort_und_Ausstattung:neutral             9
# Komfort_und_Ausstattung:positive            6
# QR-Code:negative                            0
# QR-Code:neutral                             1
# QR-Code:positive                            0
# Reisen_mit_Kindern:negative                 5
# Reisen_mit_Kindern:neutral                  2
# Reisen_mit_Kindern:positive                 0
# Service_und_Kundenbetreuung:negative       36
# Service_und_Kundenbetreuung:neutral        17
# Service_und_Kundenbetreuung:positive       14
# Sicherheit:negative                        78
# Sicherheit:neutral                          3
# Sicherheit:positive                         6
# Sonstige_Unregelmässigkeiten:negative     221
# Sonstige_Unregelmässigkeiten:neutral        5
# Sonstige_Unregelmässigkeiten:positive       3
# Ticketkauf:negative                        42
# Ticketkauf:neutral                         43
# Ticketkauf:positive                        19
# Toiletten:negative                          5
# Toiletten:neutral                           2
# Toiletten:positive                          0
# Zugfahrt:negative                         197
# Zugfahrt:neutral                           20
# Zugfahrt:positive                          34
# dtype: int64
#
# entity distribution
# ALG:NEG    1795
# SOU:NEG    1766
# ZUG:NEG    1642
# ATM:NEG    1063
# ALG:POS    1029
# SIC:NEG     826
# TIC:NEG     462
# ZUG:POS     395
# SUK:NEG     330
# INF:NEG     247
# CON:NEG     230
# AUP:NEG     224
# ATM:NEU     211
# ZUG:NEU     151
# ATM:POS     131
# SUK:POS     128
# ALG:NEU     123
# APP:NEG     119
# TIC:NEU     107
# TIC:POS      90
# SOU:NEU      89
# KUA:NEG      88
# APP:NEU      72
# CON:POS      68
# INF:NEU      64
# SOU:POS      63
# CON:NEU      62
# SUK:NEU      46
# BAF:NEG      44
# INF:POS      43
# AUP:POS      40
# APP:POS      37
# TOI:NEG      37
# KUA:POS      36
# IMG:NEG      29
# GST:NEG      26
# KUA:NEU      21
# SIC:POS      19
# RMK:NEG      19
# BAF:POS      15
# DSG:NEG      15
# RMK:NEU      15
# SIC:NEU      14
# DSG:POS      14
# BAF:NEU      13
# IMG:NEU      11
# TOI:NEU      10
# RMK:POS       9
# GST:NEU       9
# AUP:NEU       8
# GST:POS       8
# IMG:POS       8
# GEP:NEU       7
# GEP:NEG       6
# DSG:NEU       3
# TOI:POS       2
# Name: bio_tags, dtype: int64

# %% [markdown]
# ## Diachronic test data

# %%
desc_analysis(test_dia_df, test_dia_df_op, test_dia_df_cat, test_dia_df_cat_pol, cats, cats_pol)
# Out:
# complete number of observations
# 1842
#
# relevance distribution
# col_0      count
# relevance
# True        1547
# False        295
#
# sentiment distribution
# col_0      count
# sentiment
# neutral     1237
# negative     497
# positive     108
#
# aspect distribution of documents with opinion
# col_0                         count
# aspect
# Allgemein                      1042
# Sonstige_Unregelmässigkeiten    276
# Zugfahrt                        250
# Connectivity                    108
# Atmosphäre                      101
# Sicherheit                       80
# Ticketkauf                       63
# Informationen                    39
# Service_und_Kundenbetreuung      29
# DB_App_und_Website               26
# Auslastung_und_Platzangebot      23
# Toiletten                        12
# Komfort_und_Ausstattung          11
# Gepäck                            6
# Gastronomisches_Angebot           4
# Image                             4
# Barrierefreiheit                  2
# Design                            2
# Reisen_mit_Kindern                2
#
# col_0                                  count
# aspect_polarity
# Allgemein:neutral                        913
# nan:nan                                  295
# Sonstige_Unregelmässigkeiten:negative    271
# Zugfahrt:negative                        203
# Allgemein:negative                        87
# Atmosphäre:negative                       81
# Sicherheit:negative                       75
# Connectivity:negative                     59
# Allgemein:positive                        42
# Connectivity:positive                     42
# Ticketkauf:negative                       41
# Zugfahrt:positive                         40
# Informationen:negative                    30
# Service_und_Kundenbetreuung:negative      23
# DB_App_und_Website:negative               20
# Auslastung_und_Platzangebot:negative      19
# Ticketkauf:neutral                        13
# Toiletten:negative                        12
# Atmosphäre:positive                       10
# Atmosphäre:neutral                        10
# Ticketkauf:positive                        9
# Komfort_und_Ausstattung:negative           8
# Zugfahrt:neutral                           7
# Informationen:positive                     7
# Connectivity:neutral                       7
# Sicherheit:positive                        5
# DB_App_und_Website:neutral                 5
# Service_und_Kundenbetreuung:positive       4
# Auslastung_und_Platzangebot:positive       4
# Sonstige_Unregelmässigkeiten:positive      4
# Image:negative                             4
# Gepäck:negative                            4
# Gastronomisches_Angebot:negative           3
# Komfort_und_Ausstattung:positive           3
# Service_und_Kundenbetreuung:neutral        2
# Informationen:neutral                      2
# Gastronomisches_Angebot:neutral            1
# Reisen_mit_Kindern:neutral                 1
# Design:positive                            1
# Sonstige_Unregelmässigkeiten:neutral       1
# Reisen_mit_Kindern:negative                1
# Design:negative                            1
# DB_App_und_Website:positive                1
# Barrierefreiheit:positive                  1
# Barrierefreiheit:negative                  1
# Gepäck:neutral                             1
# Gepäck:positive                            1
# total documents:  24816
#
# aspect distribution without multiple
# Allgemein                       1024
# Atmosphäre                        53
# Informationen                     35
# DB_App_und_Website                18
# Auslastung_und_Platzangebot       20
# Sonstige_Unregelmässigkeiten     164
# Zugfahrt                         184
# Ticketkauf                        48
# Sicherheit                        42
# Barrierefreiheit                   2
# Service_und_Kundenbetreuung       27
# Connectivity                      73
# Komfort_und_Ausstattung           11
# Toiletten                          4
# Gastronomisches_Angebot            3
# Image                              3
# Design                             2
# Reisen_mit_Kindern                 2
# Gepäck                             6
# QR-Code                            0
# dtype: int64
# Allgemein:negative                        80
# Allgemein:neutral                        913
# Allgemein:positive                        33
# Atmosphäre:negative                       39
# Atmosphäre:neutral                        10
# Atmosphäre:positive                        7
# Auslastung_und_Platzangebot:negative      17
# Auslastung_und_Platzangebot:neutral        0
# Auslastung_und_Platzangebot:positive       3
# Barrierefreiheit:negative                  1
# Barrierefreiheit:neutral                   0
# Barrierefreiheit:positive                  1
# Connectivity:negative                     46
# Connectivity:neutral                       7
# Connectivity:positive                     28
# DB_App_und_Website:negative               14
# DB_App_und_Website:neutral                 4
# DB_App_und_Website:positive                1
# Design:negative                            1
# Design:neutral                             0
# Design:positive                            1
# Gastronomisches_Angebot:negative           2
# Gastronomisches_Angebot:neutral            1
# Gastronomisches_Angebot:positive           0
# Gepäck:negative                            4
# Gepäck:neutral                             1
# Gepäck:positive                            1
# Image:negative                             3
# Image:neutral                              0
# Image:positive                             0
# Informationen:negative                    26
# Informationen:neutral                      2
# Informationen:positive                     7
# Komfort_und_Ausstattung:negative           8
# Komfort_und_Ausstattung:neutral            0
# Komfort_und_Ausstattung:positive           3
# QR-Code:negative                           0
# QR-Code:neutral                            0
# QR-Code:positive                           0
# Reisen_mit_Kindern:negative                1
# Reisen_mit_Kindern:neutral                 1
# Reisen_mit_Kindern:positive                0
# Service_und_Kundenbetreuung:negative      21
# Service_und_Kundenbetreuung:neutral        2
# Service_und_Kundenbetreuung:positive       4
# Sicherheit:negative                       39
# Sicherheit:neutral                         0
# Sicherheit:positive                        3
# Sonstige_Unregelmässigkeiten:negative    159
# Sonstige_Unregelmässigkeiten:neutral       1
# Sonstige_Unregelmässigkeiten:positive      4
# Ticketkauf:negative                       34
# Ticketkauf:neutral                        11
# Ticketkauf:positive                        8
# Toiletten:negative                         4
# Toiletten:neutral                          0
# Toiletten:positive                         0
# Zugfahrt:negative                        149
# Zugfahrt:neutral                           5
# Zugfahrt:positive                         34
# dtype: int64
#
# entity distribution
# ALG:NEG    1795
# SOU:NEG    1766
# ZUG:NEG    1642
# ATM:NEG    1063
# ALG:POS    1029
# SIC:NEG     826
# TIC:NEG     462
# ZUG:POS     395
# SUK:NEG     330
# INF:NEG     247
# CON:NEG     230
# AUP:NEG     224
# ATM:NEU     211
# ZUG:NEU     151
# ATM:POS     131
# SUK:POS     128
# ALG:NEU     123
# APP:NEG     119
# TIC:NEU     107
# TIC:POS      90
# SOU:NEU      89
# KUA:NEG      88
# APP:NEU      72
# CON:POS      68
# INF:NEU      64
# SOU:POS      63
# CON:NEU      62
# SUK:NEU      46
# BAF:NEG      44
# INF:POS      43
# AUP:POS      40
# APP:POS      37
# TOI:NEG      37
# KUA:POS      36
# IMG:NEG      29
# GST:NEG      26
# KUA:NEU      21
# SIC:POS      19
# RMK:NEG      19
# BAF:POS      15
# DSG:NEG      15
# RMK:NEU      15
# SIC:NEU      14
# DSG:POS      14
# BAF:NEU      13
# IMG:NEU      11
# TOI:NEU      10
# RMK:POS       9
# GST:NEU       9
# AUP:NEU       8
# GST:POS       8
# IMG:POS       8
# GEP:NEU       7
# GEP:NEG       6
# DSG:NEU       3
# TOI:POS       2
# Name: bio_tags, dtype: int64
